# %% [markdown]
# Import Keras and other necessary libraries:

# %%
import datascience as ds
from datascience import *
import numpy as np
from graphviz import Source
import pandas as pd
import re
import string
from copy import copy
import nltk
from datetime import datetime

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier as XGBoostClassifier
from sklearn import tree
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
import seaborn as sns
from imblearn.over_sampling import SMOTE

from keras import backend as K
from keras.models import Model
from keras.layers import Input, Dense, Lambda, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

import gensim
# %matplotlib inline

# %% [markdown]
# Read data and set train/validation/test split:

# %%
#read the dataset
csv = pd.read_csv("/home/karen/workspace/data_science/Datasci_Fall_18/ds200/Labs/lab5/cleaned_tagged.csv")

test_split = 0.3 #portion of data used for testing
val_split = 0.2 #portion of training data used for validation

# %% [markdown]
# Prepare training, validation and test datasets:

# %%
tagged = csv.copy()
Relevant = np.array([0]*tagged.size)
Relevant[tagged[tagged.sentiment!=-1].index.tolist()] = 1
tagged['Relevant'] = pd.Series(Relevant, name='Relevant')
tagged = tagged.drop(tagged.columns[0], axis=1).reset_index(drop=True)
tagged
# Out:
#                   user_id                        user_name  \
# 0      802657195661742080                 Christine Warren
# 1     1039245812230893570                   Trumpservative
# 2               282084840      Darrel Sheldon #MAGAVETERAN
# 3                62315639   Queer Liberal Voting Snowflake
# 4      823307049266245633           don jones #veteran (K)
# 5               340428574                         DelcoGal
# 6              1603928228                             Julz
# 7              1865678516                Barbara Kuczinski
# 8                59288409                   Josh Steed PhD
# 9               325172419                        Mrs. Linz
# 10             2283127514                    Garrett ODowd
# 11               17419972                         AlanaP98
# 12     961845634889236482                   Mahgdalen Rose
# 13             2678120572             Steven Christopher I
# 14               21328716                    Lisa Resists
# 15              632186707                  Patricia Torney
# 16     708480956957646848                             Dana
# 17              125361184                        AZCowgirl
# 18             2409177088                     PantherElvis
# 19     912292486000795648               God Country Family
# 20              360343192               Daisy's can opener
# 21     751291181586190336                 Marco Del Chiaro
# 22     952981731900116992                             vic
# 23     830136290742001666                         V Torcia
# 24     715349560491520000                     James DeLong
# 25             1942789135          Haifisch Von Eisenhardt
# 26               21593725                Sallee #chercrew
# 27     810822426783318016                        Kim White
# 28               63761348                     Made In USA
# 29             2992849735                    Kathryn Moore
# ...                   ...                              ...
# 1266           2945430552                    moises esmena
# 1267   816141849282756608                    cjporterfield
# 1268           3328076603                 Right Got Tweets
# 1269             66034438  Jackie Barker ANDIAMO-Let's Go!
# 1270   802325442682355712                          Bbarber
# 1271             26907779                 lAmTheResistance
# 1272           2387868601                           Robert
# 1273           3353307131             Deplorable ladybella
# 1274             49176576                            Steve
# 1275             66034438  Jackie Barker ANDIAMO-Let's Go!
# 1276   973493306108739584                   TheSpeaker2018
# 1277   749849002762313728                 Russ T. Trombone
# 1278  1012747092475940864                         MyNation
# 1279             66034438  Jackie Barker ANDIAMO-Let's Go!
# 1280   704314463525150721                        Alexander
# 1281            272578495                               BK
# 1282   965992281043062784                    ProsperousUSA
# 1283             18927224                          tbblacz
# 1284   890277711188512768                           Chloe
# 27    gerfingerpoken barack hussein obama leader of ...          0         1
# 28    brush1776 hard to believe potus isnt followed ...          2         1
# 29    lvnancy the question of the day for libtards d...          0         1
# ...                                                 ...        ...       ...
# 1266  wakeupamerica presidenttrump is good in financ...          1         1
# 1267            potus time for mitch to get for thewall          0         1
# 1268  rev out the trumptrain for callmemylady 91tegg...          0         1
# 1269  iam1america liberals of america islam is not a...         -1         0
# 1270  dld867 one more person was just killed in indi...          1         1
# 1271  sencorygardner as a constituent id like to ask...          1         1
# 1272  wow and that is the truth trump also wants to ...          1         1
# 1273  robfortrump2020 president barack hussein obama...          1         1
# 1274  this individual is so arrogant that he does no...          1         1
# 1275  iam1america dear democrats and liberals of ame...          0         1
# 1276  thesharpedge1 exactly we call them fakemaga qa...          1         1
# 1277    so be very very weak on immigration donaldtrump          2         1
# 1278  views despite facing this humiliation pakistan...         -1         0
# 1279  iam1america cory booker and kamala harris are ...          2         1
# 1280  martinsherman2 trump rightly defunded unrwa an...          1         1
# 1281  jimmyfallon way to rag on potus in the monolog...          0         1
# 1282  theres nothing more dangerous than a nasty per...          2         1
# 1283  repmaxinewaters impeach you for being you your...          0         1
# 1284  janjer1 another life just lost in indiana potu...          0         1
# 1285  we dodge the hillary bullet and saved the coun...          0         1
# 1286  hi i am professional graphics designer looking...          1         1
# 1287  sauterrory live now presidenttrump donaldtrump...          1         1
# 1288  nothank you redpilled princess wethepeople gre...          0         1
# 1289  rightgottweets rev out the trumptrain for call...          0         1
# 1290  hopefully america is finally seeing through re...          0         1
# 1291  moab incoming wwg1wga unitingpatriotstogether ...         -1         0
# 1292  imagine if presidenttrump actually got some po...          1         1
# 1293  17 years from today his building became highes...          0         1
# 1294                                        oh hell yes         -1         0
# 1295  brazil 5 el salvador 0 twogoal richarlison lea...          1         1
#
# [1296 rows x 7 columns]

# %%
first_test = int(tagged.shape[0] * (1 - test_split))
first_val = int(first_test * (1 - val_split))

train = tagged.iloc[:first_val]
val = tagged.iloc[first_val:first_test]
test = tagged.iloc[first_test:]

## drop Amount and Class
x_train_df, x_val_df, x_test_df = train.iloc[:, -3], val.iloc[:, -3], test.iloc[:, -3]
y_train_df, y_val_df, y_test_df = train.iloc[:, -1], val.iloc[:, -1], test.iloc[:, -1]

x_train_df.head(), y_train_df.head()
# Out:
# (0    2 american lives were just lost in tennessee p...
#  1    realfarmacist realdonaldtrump tuckercarlson ou...
#  2    rightgottweets rev out the trumptrain for blue...
#  3    tennessee is suffering after shooting takes 2 ...
#  4    sassytjoy bcmsolt fightinirish109 dybarb wolfi...
#  Name: text, dtype: object, 0    1
#  1    1
#  2    1
#  3    1
#  4    0
#  Name: Relevant, dtype: int64)

# %%
x_train, x_val, x_test = x_train_df.values, x_val_df.values, x_test_df.values
y_train, y_val, y_test = y_train_df.values, y_val_df.values, y_test_df.values

# scaler = preprocessing.StandardScaler()
vect = TfidfVectorizer(sublinear_tf=True, min_df=10, norm='l1', encoding='latin-1', 
                        ngram_range=(1,2), stop_words='english')
vect = CountVectorizer(
     analyzer="word", ngram_range=([1,2]), tokenizer=nltk.word_tokenize,
    preprocessor=None, stop_words='english', max_features=3000)

x_train, x_val, x_test = vect.fit_transform(x_train), vect.transform(x_val), vect.transform(x_test)
x_train.shape, x_val.shape, x_test.shape
# Out:
# ((725, 3000), (182, 3000), (389, 3000))

# %% [markdown]
# Build the model and print summary:

# %%
hidden_size = 16 #size of the hidden layer in encoder and decoder
latent_dim = 2 #number of latent variables to learn

input_dim = x_train.shape[1]

x = Input(shape=(input_dim,))
t = BatchNormalization()(x)
t = Dense(hidden_size, activation='tanh' , name='encoder_hidden')(t)
t = BatchNormalization()(t)

z_mean = Dense(latent_dim, name='z_mean')(t)
z_log_var = Dense(latent_dim, name='z_log_var')(t)

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=K.shape(z_mean), mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var / 2) * epsilon

z = Lambda(sampling, name='z_sampled')([z_mean, z_log_var])
#t = BatchNormalization()(z)

t = Dense(hidden_size, activation='tanh', name='decoder_hidden')(z)
#t = BatchNormalization()(t)

decoded_mean = Dense(input_dim, activation=None, name='decoded_mean')(t)

vae = Model(x, decoded_mean)

def rec_loss(y_true, y_pred):
    return K.sum(K.square(y_true - y_pred), axis=-1)

def kl_loss(y_true, y_pred):
    return - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)

def vae_loss(x, decoded_mean):
    rec_loss = K.sum(K.square(x - decoded_mean), axis=-1)
    kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return K.mean((rec_loss + kl_loss) / 2)

vae.compile(optimizer=Adam(lr=1e-2), loss=vae_loss, metrics=[rec_loss, kl_loss])
vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 3000)         0
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 3000)         12000       input_4[0][0]
# __________________________________________________________________________________________________
# encoder_hidden (Dense)          (None, 16)           48016       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16)           64          encoder_hidden[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            34          batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            34          batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# z_sampled (Lambda)              (None, 2)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# decoder_hidden (Dense)          (None, 16)           48          z_sampled[0][0]
# __________________________________________________________________________________________________
# decoded_mean (Dense)            (None, 3000)         51000       decoder_hidden[0][0]
# ==================================================================================================
# Total params: 111,196
# Trainable params: 105,164
# Non-trainable params: 6,032
# __________________________________________________________________________________________________

# %% [markdown]
# Train the model with early stopping and a kind of learning rate schedule for the specified number of epochs with the specified batch size:

# %%
x_train.shape, x_test.shape
# Out:
# ((725, 3000), (389, 3000))

# %%
n_epochs = 30
batch_size = 128

early_stopping = EarlyStopping(monitor='loss', patience=10) #stop training if loss does not decrease with at least 0.00001
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=5, factor=0.2) #reduce learning rate (divide it by 5 = multiply it by 0.2) if loss does not decrease with at least 0.00001

callbacks = [early_stopping, reduce_lr]

#collect training data in history object
history = vae.fit(x_train, x_train, 
                  validation_data=(x_val, x_val), 
                  batch_size=batch_size, epochs=n_epochs, 
                  callbacks=callbacks)
# Out:
# Train on 725 samples, validate on 182 samples
# Epoch 1/30
# Epoch 29/30
# 725/725 [==============================] - 0s 480us/step - loss: 5.8449 - rec_loss: 11.6758 - kl_loss: 0.0140 - val_loss: 3.5347 - val_rec_loss: 7.0577 - val_kl_loss: 0.0117
# Epoch 30/30
# 725/725 [==============================] - 0s 455us/step - loss: 5.8441 - rec_loss: 11.6714 - kl_loss: 0.0169 - val_loss: 3.5361 - val_rec_loss: 7.0618 - val_kl_loss: 0.0103

# %% [markdown]
# Plotting training and validation loss:

# %%
fig = plt.figure(figsize=(14, 6))
ax = fig.gca()
ax.plot(history.history['rec_loss'], c='r');
ax.plot(history.history['val_rec_loss']);

# %% [markdown]
# Plotting the learned latent representations for normal and anomalous instances in the specified dataset (training/validation/test):

# %%
Model
# Out:
# keras.engine.training.Model

# %%
x_data = x_train.todense()
y_data = y_train

encoder = Model(x, z_mean)

with_labels = np.concatenate([x_data, np.reshape(y_data, (-1, 1))], axis=1) #concatenate x and y to be able to filter by class

with_labels = pd.DataFrame(with_labels)
irrelevant = with_labels.iloc[np.where(with_labels.iloc[:, -1] == 0)]
relevant = with_labels.iloc[np.where(with_labels.iloc[:, -1] == 1)]
irrelevant_encoded = encoder.predict(irrelevant.iloc[:, :-1], batch_size=128)
relevant_encoded = encoder.predict(relevant.iloc[:, :-1], batch_size=128)

fig = plt.figure(figsize=(6, 6))
ax = fig.gca()
ax.scatter(relevant_encoded[:, 0], relevant_encoded[:, 1], c='b')
ax.scatter(irrelevant_encoded[:, 0], irrelevant_encoded[:, 1], c='r')

# %%
with_labels_encoded = encoder.predict(with_labels.iloc[:, :-1], batch_size=128)

X = with_labels_encoded
y = with_labels.iloc[:, -1]

clf = DecisionTreeClassifier(criterion = 'entropy',
                            random_state = 100,
                            max_depth = 25,
                            min_samples_leaf = 2)
clf.fit(X, y)

pred = clf.predict(X)

print('Cross_val_score:', np.mean([cross_val_score(clf, X, y, cv=8)]))
print("AUC(ROC): " + str(metrics.roc_auc_score(y, pred)))
print("Precision: " + str(metrics.precision_score(y, pred)))
print("Recall: " + str(metrics.recall_score(y, pred)))
print("F1 score: " + str(metrics.f1_score(y, pred)))

tn, fp, fn, tp = metrics.confusion_matrix(y, pred).ravel()

print("False positives: " + str(fp))
print("True positives: " + str(tp))
print("False negatives: " + str(fn))
print("True negateives: " + str(tn))
cm = metrics.confusion_matrix(y, pred)
# Out:
# Cross_val_score: 0.7516941391941392
# AUC(ROC): 0.9294277151420008
# Precision: 0.9869494290375204
# Recall: 0.9497645211930926
# F1 score: 0.968
# False positives: 8
# True positives: 605
# False negatives: 32
# True negateives: 80

# %%
def plot_cm(cm, title='Confusion matrix', cmap=plt.cm.YlGnBu, classes=['Relevant', 'Irrelevant']):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    target_names = classes
    plt.xticks(tick_marks, target_names, rotation=45)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm
# Out:
# array([[ 80,   8],
#        [ 32, 605]])

# %%
plot_cm(cm)
